# %%
'''
parameters of simulations
Nx1 - число точек в первом измерении
Nx2 - число точек во втором измерении
setup - модель
setup = 'RTI' - RT instability, Nx1 = 128, Nx2 = Nx1/2
setup = 'KHI' - KH instability, Nx1 = Nx2 = xx
setup = 'BW1D', Nx1 = xx, Nx2 = 1 
setup = 'DBW1D', Nx1 = xx, Nx2 = 1
setup = 'expl2D', Nx1 = Nx2 = xx
setup = 'OT2D', Nx1 = Nx2 = xx
flux_type = 'LLF', 'HLL'
rec_type = 'PCM', 'PLM', 'PPM', 'PPMorig', 'WENO'
RK_integr = 'RK1', 'RK2', 'RK3' 
'''
from piastra2D_easy_mhd import *
Nx1 = 64
Nx2 = 64
setup = 'expl2D'
CFL = 0.4
flux_type = 'HLL'
rec_type = 'PPM'
RK_integr = 'RK3'


easy_mhd_solver_call(Nx1, Nx2, setup, CFL, flux_type, rec_type, RK_integr)
# Out:
# magnetized explosion test
# grid resolution =  64 64
# reconstruction type =  PPM
# Riemann flux =  HLL
# Temporal integration =  RK3
# final phys time =  0.2
# START OF SIMULATION
# phys time =  0.013089885345963408
# num of timesteps =  10
# phys time =  0.024324746743500967
# num of timesteps =  20
# phys time =  0.03550802016812146
# num of timesteps =  30
# phys time =  0.04790736617089179
# num of timesteps =  40
# phys time =  0.06197108069995621
# num of timesteps =  50
# phys time =  0.07764332620216581
# num of timesteps =  60
# phys time =  0.09425586881126613
# num of timesteps =  70
# phys time =  0.11188595376226168
# num of timesteps =  80
# phys time =  0.12915144990410002
# num of timesteps =  90
# phys time =  0.14538350069248604
# num of timesteps =  100
# phys time =  0.16206028261257585
# num of timesteps =  110
# phys time =  0.17950592490391493
# num of timesteps =  120
# phys time =  0.19729930647965832
# num of timesteps =  130
# phys time =  0.2
# num of timesteps =  132
# final phys time =  0.2
# END OF SIMULATION
# time of simulation =  3.6345419883728027  secs
