# %%
'''
parameters of simulations
Nx1 - число точек в первом измерении
Nx2 - число точек во втором измерении
setup - модель
setup = '2D' - Nx1 = Nx2 = xx
setup = '1D', Nx1 = xx, Nx2 = 1 
flux_type = 'adv', 'LW'
rec_type = 'PCM', 'PLM', 'PPM', 'PPMorig', 'WENO'
RK_integr = 'RK1', 'RK2', 'RK3' 
'''
from piastra2D_easy_advection import *
Nx1 = 64
Nx2 = 64
setup = '2D'
CFL = 0.4 
flux_type = 'adv'
rec_type = 'PPM'
RK_integr = 'RK3'

easy_advection_solver_call(Nx1, Nx2, setup, CFL, flux_type, rec_type, RK_integr)
# Out:
# linear advection test problem
# grid resolution =  64 64
# reconstruction type =  PPM
# Temporal integration =  RK3
# final phys time =  1.0
# START OF SIMULATION
# phys time =  0.037499999999999624
# num of timesteps =  6
# phys time =  0.07499999999999925
# num of timesteps =  12
# phys time =  0.11249999999999886
# num of timesteps =  18
# phys time =  0.14999999999999852
# num of timesteps =  24
# phys time =  0.18749999999999822
# num of timesteps =  30
# phys time =  0.22499999999999792
# num of timesteps =  36
# phys time =  0.26249999999999757
# num of timesteps =  42
# phys time =  0.2999999999999971
# num of timesteps =  48
# phys time =  0.33749999999999664
# num of timesteps =  54
# phys time =  0.37499999999999617
# num of timesteps =  60
# phys time =  0.4124999999999957
# num of timesteps =  66
# phys time =  0.44999999999999524
# num of timesteps =  72
# phys time =  0.48749999999999477
# num of timesteps =  78
# phys time =  0.5249999999999945
# num of timesteps =  84
# phys time =  0.5624999999999943
# num of timesteps =  90
# phys time =  0.5999999999999942
# num of timesteps =  96
# phys time =  0.6374999999999941
# num of timesteps =  102
# phys time =  0.6749999999999939
# num of timesteps =  108
# phys time =  0.7124999999999938
# num of timesteps =  114
# phys time =  0.7499999999999937
# num of timesteps =  120
# phys time =  0.7874999999999935
# num of timesteps =  126
# phys time =  0.8249999999999934
# num of timesteps =  132
# phys time =  0.8624999999999933
# num of timesteps =  138
# phys time =  0.8999999999999931
# num of timesteps =  144
# phys time =  0.937499999999993
# num of timesteps =  150
# phys time =  0.9749999999999929
# num of timesteps =  156
# phys time =  0.9999999999999928
# num of timesteps =  160
# phys time =  1.0
# num of timesteps =  161
# final phys time =  1.0
# END OF SIMULATION
# time of simulation =  1.8627080917358398  secs
